# %% [markdown]
# <a href="https://colab.research.google.com/github/OlesyaSel/2020_CPK_Python_for_Data_Analysis-4/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from youtube_transcript_api import YouTubeTranscriptApi
 
srt = YouTubeTranscriptApi.get_transcript("lBtbbjH0YOQ&list=PL5lOgFOYdvjgcP0tYwvx8AxiiH2AMMvuG&index=2",
                                          languages=['en'])

print(srt)
# Out:
# [{'text': 'tell me if you know at the ending should', 'start': 27.119, 'duration': 6.731}, {'text': "be then just tell me don't say", 'start': 31.689, 'duration': 8.101}, {'text': 'surprising and inevitable but in this', 'start': 33.85, 'duration': 7.35}, {'text': "story what does that mean you've got her", 'start': 39.79, 'duration': 2.94}, {'text': 'at the top of a building she takes a', 'start': 41.2, 'duration': 4.08}, {'text': 'step off you set up her belief in God', 'start': 42.73, 'duration': 5.64}, {'text': 'some belief in some God and we hope it', 'start': 45.28, 'duration': 32.67}, {'text': "will be surprising it's all mad I wonder", 'start': 48.37, 'duration': 31.109}, {'text': 'if it applies to everybody on the face', 'start': 77.95, 'duration': 3.93}, {'text': "of the earth are you feeling that you're", 'start': 79.479, 'duration': 3.511}, {'text': "close and you're wanting me to validate", 'start': 81.88, 'duration': 2.669}, {'text': "the work you've done so far are you
# ...
